# %% [markdown]
# # 1.OS Error

# %%
#!pip install spacy
# %pip install typing-extensions --upgrade

# %%
import spacy
nlp = spacy_load("en_core_web_sm")
# namespace error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import spacy
# ----> 2 nlp = spacy_load("en_core_web_sm")
#
# NameError: name 'spacy_load' is not defined

# %% [markdown]
# # 1.Solution

# %%
import spacy
import os

# Download the model first if not available
os.system("python -m spacy download en_core_web_sm")

# Then load
nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 31.6 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # 2.Error: ModuleNotFoundError for TextBlob

# %%
from textblob import TextBlob
blob = TextBlob("TextBlob is amazing.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from textblob import TextBlob
#       2 blob = TextBlob("TextBlob is amazing.")
#
# ModuleNotFoundError: No module named 'textblob'

# %% [markdown]
# # 2.Solution

# %%
# !pip install textblob
from textblob import TextBlob
blob = TextBlob("TextBlob is amazing.")
print(blob.sentiment)
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (1.5.2)
# Collecting regex>=2021.8.3 (from nltk>=3.9->textblob)
#   Downloading regex-2026.1.15-cp311-cp311-macosx_10_9_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (4.67.1)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 7.8 MB/s  0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.9 MB/s  0:00:00
# Downloading regex-2026.1.15-cp311-cp311-macosx_10_9_x86_64.whl (290 kB)
# Installing collected packages: regex, nltk, textblob
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [textblob]1/3 [nltk]
# Successfully installed nltk-3.9.2 regex-2026.1.15 textblob-0.19.0
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)

# %% [markdown]
# # 3.AttributeError

# %%
from sklearn.feature_extraction.text import CountVectorizer
texts = [123, 456]  # numeric values instead of strings
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 texts = [123, 456]  # numeric values instead of strings
#       3 vectorizer = CountVectorizer()
# ----> 4 X = vectorizer.fit_transform(texts)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1377, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1369             warnings.warn(
#    1370                 "Upper case characters found in"
#    1371                 " vocabulary while 'lowercase'"
#    1372                 " is True. These entries will not"
#    1373                 " be matched with any documents"
#    1374             )
#    1375             break
# -> 1377 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1379 if self.binary:
#    1380     X.data.fill(1)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1264, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1262 for doc in raw_documents:
#    1263     feature_counter = {}
# -> 1264     for feature in analyze(doc):
#    1265         try:
#    1266             feature_idx = vocabulary[feature]
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:104, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     102 else:
#     103     if preprocessor is not None:
# --> 104         doc = preprocessor(doc)
#     105     if tokenizer is not None:
#     106         doc = tokenizer(doc)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:62, in _preprocess(doc, accent_function, lower)
#      43 """Chain together an optional series of text preprocessing steps to
#      44 apply to a document.
#      45
#    (...)     59     preprocessed string
#      60 """
#      61 if lower:
# ---> 62     doc = doc.lower()
#      63 if accent_function is not None:
#      64     doc = accent_function(doc)
#
# AttributeError: 'int' object has no attribute 'lower'

# %% [markdown]
# # 3.Solution

# %%
from sklearn.feature_extraction.text import CountVectorizer
texts = ["text one", "text two"]  # must be strings
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)
print(X.toarray())
# Out:
# [[1 1 0]
#  [0 1 1]]

# %% [markdown]
# # 4.Attribute Error

# %%
from nltk.corpus import stopwords
stop_words = stopwords.word('english')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/nltk/corpus/util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/Users/harikrishnan/nltk_data'
#     - '/Users/harikrishnan/Documents/anaconda3/envs/myenv/nltk_data'
#     - '/Users/harikrishnan/Documents/anaconda3/envs/myenv/share/nltk_data'
#     - '/Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 from nltk.corpus import stopwords
# ----> 2 stop_words = stopwords.word('english')
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/nltk/corpus/util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/nltk/corpus/util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/nltk/corpus/util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/Users/harikrishnan/nltk_data'
#     - '/Users/harikrishnan/Documents/anaconda3/envs/myenv/nltk_data'
#     - '/Users/harikrishnan/Documents/anaconda3/envs/myenv/share/nltk_data'
#     - '/Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# # 4.Solution

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = stopwords.words('english')
print(stop_words[:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/harikrishnan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # 5.ValueError

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X = tfidf.fit_transform("single string instead of list")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 tfidf = TfidfVectorizer()
# ----> 3 X = tfidf.fit_transform("single string instead of list")
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:2105, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2098 self._check_params()
#    2099 self._tfidf = TfidfTransformer(
#    2100     norm=self.norm,
#    2101     use_idf=self.use_idf,
#    2102     smooth_idf=self.smooth_idf,
#    2103     sublinear_tf=self.sublinear_tf,
#    2104 )
# -> 2105 X = super().fit_transform(raw_documents)
#    2106 self._tfidf.fit(X)
#    2107 # X is already a transformed view of raw_documents so
#    2108 # we set copy to False
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1355, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1351 # We intentionally don't call the transform method to make
#    1352 # fit_transform overridable without unwanted side effects in
#    1353 # TfidfVectorizer.
#    1354 if isinstance(raw_documents, str):
# -> 1355     raise ValueError(
#    1356         "Iterable over raw text documents expected, string object received."
#    1357     )
#    1359 self._validate_ngram_range()
#    1360 self._warn_for_unused_params()
#
# ValueError: Iterable over raw text documents expected, string object received.

# %% [markdown]
# # 5.Solution

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(["sentence one", "sentence two"])
print(X.toarray())
# Out:
# [[0.81480247 0.57973867 0.        ]
#  [0.         0.57973867 0.81480247]]

# %% [markdown]
# # 6.NameError

# %%
from wordcloud import WordCloud
wc = WordCloud(stopwords=STOPWORDS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from wordcloud import WordCloud
# ----> 2 wc = WordCloud(stopwords=STOPWORDS)
#
# NameError: name 'STOPWORDS' is not defined

# %% [markdown]
# # 6.Solution

# %%
from wordcloud import WordCloud, STOPWORDS
wc = WordCloud(stopwords=STOPWORDS)
