# %% [markdown]
# # 1.ValueError

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform("Just one sentence.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 vectorizer = TfidfVectorizer()
# ----> 3 X = vectorizer.fit_transform("Just one sentence.")
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:2105, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2098 self._check_params()
#    2099 self._tfidf = TfidfTransformer(
#    2100     norm=self.norm,
#    2101     use_idf=self.use_idf,
#    2102     smooth_idf=self.smooth_idf,
#    2103     sublinear_tf=self.sublinear_tf,
#    2104 )
# -> 2105 X = super().fit_transform(raw_documents)
#    2106 self._tfidf.fit(X)
#    2107 # X is already a transformed view of raw_documents so
#    2108 # we set copy to False
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1355, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1351 # We intentionally don't call the transform method to make
#    1352 # fit_transform overridable without unwanted side effects in
#    1353 # TfidfVectorizer.
#    1354 if isinstance(raw_documents, str):
# -> 1355     raise ValueError(
#    1356         "Iterable over raw text documents expected, string object received."
#    1357     )
#    1359 self._validate_ngram_range()
#    1360 self._warn_for_unused_params()
#
# ValueError: Iterable over raw text documents expected, string object received.

# %% [markdown]
# # 1. Solution

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(["Just one sentence."])

# %% [markdown]
# # 2.ImportError

# %%
from textblob import textBlob
TextBlob("Great work!").sentiment
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from textblob import textBlob
#       2 TextBlob("Great work!").sentiment
#
# ImportError: cannot import name 'textBlob' from 'textblob' (/Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/textblob/__init__.py)

# %% [markdown]
# # 2.Solution

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (2026.1.15)
# Requirement already satisfied: tqdm in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
from textblob import TextBlob
print(TextBlob("Great work!").sentiment)
# Out:
# Sentiment(polarity=1.0, subjectivity=0.75)

# %% [markdown]
# # 3.ValueError

# %%
from gensim import corpora, models
corpus = []
lda = models.LdaModel(corpus=corpus, num_topics=2, id2word=None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from gensim import corpora, models
#       2 corpus = []
#       3 lda = models.LdaModel(corpus=corpus, num_topics=2, id2word=None)
#
# ModuleNotFoundError: No module named 'gensim'

# %% [markdown]
#  # 3.Solution

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages (from smart_open>=1.8.1->gensim) (1.14.2)
# Downloading gensim-4.4.0-cp311-cp311-macosx_10_9_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 23.1 MB/s  0:00:01 eta 0:00:01
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
from gensim import corpora

texts = [["cat", "dog", "mouse"], ["dog", "lion"]]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]
lda = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       4 dictionary = corpora.Dictionary(texts)
#       5 corpus = [dictionary.doc2bow(text) for text in texts]
# ----> 6 lda = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=2)
#
# NameError: name 'models' is not defined

# %% [markdown]
# # 4.AttributeError

# %%
from sklearn.feature_extraction.text import CountVectorizer
docs = [1234, 5678]
cv = CountVectorizer()
cv.fit_transform(docs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       2 docs = [1234, 5678]
#       3 cv = CountVectorizer()
# ----> 4 cv.fit_transform(docs)
#
# File ~\anaconda3\envs\nlp\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\nlp\Lib\site-packages\sklearn\feature_extraction\text.py:1389, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1381             warnings.warn(
#    1382                 "Upper case characters found in"
#    1383                 " vocabulary while 'lowercase'"
#    1384                 " is True. These entries will not"
#    1385                 " be matched with any documents"
#    1386             )
#    1387             break
# -> 1389 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1391 if self.binary:
#    1392     X.data.fill(1)
#
# File ~\anaconda3\envs\nlp\Lib\site-packages\sklearn\feature_extraction\text.py:1276, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1274 for doc in raw_documents:
#    1275     feature_counter = {}
# -> 1276     for feature in analyze(doc):
#    1277         try:
#    1278             feature_idx = vocabulary[feature]
#
# File ~\anaconda3\envs\nlp\Lib\site-packages\sklearn\feature_extraction\text.py:110, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     108 else:
#     109     if preprocessor is not None:
# --> 110         doc = preprocessor(doc)
#     111     if tokenizer is not None:
#     112         doc = tokenizer(doc)
#
# File ~\anaconda3\envs\nlp\Lib\site-packages\sklearn\feature_extraction\text.py:68, in _preprocess(doc, accent_function, lower)
#      49 """Chain together an optional series of text preprocessing steps to
#      50 apply to a document.
#      51
#    (...)
#      65     preprocessed string
#      66 """
#      67 if lower:
# ---> 68     doc = doc.lower()
#      69 if accent_function is not None:
#      70     doc = accent_function(doc)
#
# AttributeError: 'int' object has no attribute 'lower'

# %% [markdown]
# # 4.Solution

# %%
from sklearn.feature_extraction.text import CountVectorizer
docs = ["Number one", "Number two"]
cv = CountVectorizer()
cv.fit_transform(docs)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 4 stored elements and shape (2, 3)>

# %% [markdown]
# # 5.TypeError

# %%
from wordcloud import WordCloud
import pandas as pd

df = pd.DataFrame({'text': ['This is great', None]})
text = " ".join(df['text'])
wc = WordCloud().generate(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       2 import pandas as pd
#       4 df = pd.DataFrame({'text': ['This is great', None]})
# ----> 5 text = " ".join(df['text'])
#       6 wc = WordCloud().generate(text)
#
# TypeError: sequence item 1: expected str instance, NoneType found

# %% [markdown]
# # 5.Solution

# %%
from wordcloud import WordCloud
import pandas as pd

df = pd.DataFrame({'text': ['This is great', None]})
text = " ".join(df['text'].dropna())
wc = WordCloud().generate(text)

# %% [markdown]
# # 6.TypeError

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# Create the DataFrame
df = pd.DataFrame({'text': ['This is great', None]})

# Combine non-null text
text = " ".join(df['text'].dropna())

# Generate word cloud
wc = WordCloud(background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(8, 4))
plt.imshow(text, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.title("Word Cloud Output", fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 16
#      14 # Display the word cloud
#      15 plt.figure(figsize=(8, 4))
# ---> 16 plt.imshow(text, interpolation='bilinear')
#      17 plt.axis('off')  # Hide axis
#      18 plt.title("Word Cloud Output", fontsize=16)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)   3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
#    3610         colorizer=colorizer,
#    3611         origin=origin,
#    3612         extent=extent,
#    3613         interpolation_stage=interpolation_stage,
#    3614         filternorm=filternorm,
#    3615         filterrad=filterrad,
#    3616         resample=resample,
#    3617         url=url,
#    3618         **({"data": data} if data is not None else {}),
#    3619         **kwargs,
#    3620     )
#    3621     sci(__ret)
#    3622     return __ret
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5982, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5979 if aspect is not None:
#    5980     self.set_aspect(aspect)
# -> 5982 im.set_data(X)
#    5983 im.set_alpha(alpha)
#    5984 if im.get_clip_path() is None:
#    5985     # image does not already have clipping set, clip to Axes patch
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/image.py:685, in _ImageBase.set_data(self, A)
#     683 if isinstance(A, PIL.Image.Image):
#     684     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 685 self._A = self._normalize_image_array(A)
#     686 self._imcache = None
#     687 self.stale = True
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/image.py:648, in _ImageBase._normalize_image_array(A)
#     646 A = cbook.safe_masked_invalid(A, copy=True)
#     647 if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
# --> 648     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     649                     f"converted to float")
#     650 if A.ndim == 3 and A.shape[-1] == 1:
#     651     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#
# TypeError: Image data of dtype <U13 cannot be converted to float

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# Create the DataFrame
df = pd.DataFrame({'text': ['This is great', None]})

# Combine non-null text
text = " ".join(df['text'].dropna())

# Generate word cloud
wc = WordCloud(background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(8, 4))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.title("Word Cloud Output", fontsize=16)
plt.show()
